# %% [markdown]
# <a href="https://colab.research.google.com/github/laytonmusyoki/Breast_cancer/blob/main/breast_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sb

df=pd.read_csv("/content/breast-cancer.csv")

df=df.head(20)
df
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M        17.99         10.38          122.80     1001.0
# 1     842517         M        20.57         17.77          132.90     1326.0
# 2   84300903         M        19.69         21.25          130.00     1203.0
# 3   84348301         M        11.42         20.38           77.58      386.1
# 4   84358402         M        20.29         14.34          135.10     1297.0
# 5     843786         M        12.45         15.70           82.57      477.1
# 6     844359         M        18.25         19.98          119.60     1040.0
# 7   84458202         M        13.71         20.83           90.20      577.9
# 8     844981         M        13.00         21.82           87.50      519.8
# 9   84501001         M        12.46         24.04           83.97      475.9
# 10    845636         M        16.02         23.24          102.70      797.8
# ...

# %%
x=df.drop(columns=['diagnosis'])
x.tail(10)
# Out:
#           id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 10    845636        16.02         23.24          102.70      797.8
# 11  84610002        15.78         17.89          103.60      781.0
# 12    846226        19.17         24.80          132.40     1123.0
# 13    846381        15.85         23.95          103.70      782.7
# 14  84667401        13.73         22.61           93.60      578.3
# 15  84799002        14.54         27.54           96.73      658.8
# 16    848406        14.68         20.13           94.74      684.5
# 17  84862001        16.13         20.68          108.10      798.8
# 18    849014        19.81         22.15          130.00     1260.0
# 19   8510426        13.54         14.36           87.46      566.3
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 10          0.08206           0.06669         0.03299              0.03323
# 11          0.09710           0.12920         0.09954              0.06606
# ...

# %%
y=pd.DataFrame(df.iloc[:,1])
y.head()
# Out:
#   diagnosis
# 0         M
# 1         M
# 2         M
# 3         M
# 4         M

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
from sklearn.ensemble import RandomForestClassifier


classifier=RandomForestClassifier(n_estimators=20,criterion='gini',random_state=1,max_depth=3)

classifier.fit(x_train,y_train)

# %%
y_pred=classifier.predict(x_test)

from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn

# %%
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
# Out:
# [[6]]
#               precision    recall  f1-score   support
#
#            M       1.00      1.00      1.00         6
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
# 1.0

# %%
classifier.score(x_test,y_test)
# Out:
# 1.0

# %%
plt.figure(figsize=(8,5))
sb.heatmap(cm,annot=True ,cmap=plt.cm.Blues)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(70.72222222222221, 0.5, 'Truth')

# %%
from sklearn import tree
model_tree=tree.DecisionTreeClassifier(random_state=0)
model_tree=model_tree.fit(x,y)

plt.figure(figsize=(15,10))
tree.plot_tree(model_tree,filled=True)
# Out:
# [Text(0.6, 0.8333333333333334, 'x[8] <= 0.05\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(0.4, 0.5, 'x[15] <= 0.006\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]')]
